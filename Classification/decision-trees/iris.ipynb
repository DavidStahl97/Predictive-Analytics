# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree

iris = load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
tree_iris = DecisionTreeClassifier(criterion='entropy', random_state=0)
tree_iris.fit(X_train, y_train)
y_pred = tree_iris.predict(X_test)

# %%
accuracy_score(y_true=y_test, y_pred=y_pred)
# Out:
# 1.0

# %%
plt.figure(figsize=(12, 8))
plot_tree(tree_iris, fontsize=8, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
# Out:
# [Text(334.8, 398.64, 'petal width (cm) <= 0.8\nentropy = 1.581\nsamples = 120\nvalue = [39, 37, 44]\nclass = virginica'),
#  Text(283.2923076923077, 326.15999999999997, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]\nclass = setosa'),
#  Text(386.3076923076923, 326.15999999999997, 'petal width (cm) <= 1.75\nentropy = 0.995\nsamples = 81\nvalue = [0, 37, 44]\nclass = virginica'),
#  Text(206.03076923076924, 253.67999999999998, 'petal length (cm) <= 4.95\nentropy = 0.469\nsamples = 40\nvalue = [0, 36, 4]\nclass = versicolor'),
#  Text(103.01538461538462, 181.2, 'petal width (cm) <= 1.65\nentropy = 0.187\nsamples = 35\nvalue = [0, 34, 1]\nclass = versicolor'),
#  Text(51.50769230769231, 108.71999999999997, 'entropy = 0.0\nsamples = 34\nvalue = [0, 34, 0]\nclass = versicolor'),
#  Text(154.52307692307693, 108.71999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
# ...

# %%
tree_iris = DecisionTreeClassifier(criterion='entropy',max_depth=2, random_state=0)
tree_iris.fit(X_train, y_train)
y_pred = tree_iris.predict(X_test)

# %%
accuracy_score(y_true=y_test, y_pred=y_pred)
# Out:
# 0.9666666666666667

# %%
plt.figure(figsize=(12, 8))
plot_tree(tree_iris, fontsize=8, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
# Out:
# [Text(267.84000000000003, 362.4, 'petal width (cm) <= 0.8\nentropy = 1.581\nsamples = 120\nvalue = [39, 37, 44]\nclass = virginica'),
#  Text(133.92000000000002, 217.44, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]\nclass = setosa'),
#  Text(401.76000000000005, 217.44, 'petal width (cm) <= 1.75\nentropy = 0.995\nsamples = 81\nvalue = [0, 37, 44]\nclass = virginica'),
#  Text(267.84000000000003, 72.47999999999996, 'entropy = 0.469\nsamples = 40\nvalue = [0, 36, 4]\nclass = versicolor'),
#  Text(535.6800000000001, 72.47999999999996, 'entropy = 0.165\nsamples = 41\nvalue = [0, 1, 40]\nclass = virginica')]
