# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('machinedata.csv', index_col='index')
data
# Out:
#          weight     length    height
# index
# 0      0.444182   7.595109  2.924829
# 1      0.182237   4.462217 -1.842630
# 2      1.385699   9.457622  2.042223
# 3      1.203684   8.418729  2.848723
# 4      1.474189   8.599749  3.346582
# ...         ...        ...       ...
# 95     0.362724   4.515642 -0.933595
# 96     1.446621   7.729291  1.874817
# 97     0.065792   4.771029 -0.739946
# 98     1.895526  10.498189  4.308554
# 99     0.757170   7.128484  2.023143
#
# [100 rows x 3 columns]

# %%
data.corr()
# Out:
#           weight    length    height
# weight  1.000000  0.843519  0.769490
# length  0.843519  1.000000  0.707454
# height  0.769490  0.707454  1.000000

# %%
y = data['weight'].values
X_length = data['length'].values
X_height = data['height'].values

# %%
from sklearn.linear_model import LinearRegression

regressor_length = LinearRegression()
regressor_length.fit(X_length.reshape(-1, 1), y)

regressor_height = LinearRegression()
regressor_height.fit(X_height.reshape(-1, 1), y)
# Out:
# LinearRegression()

# %%
plt.scatter(X_length, y)
plt.plot(X_length, regressor_length.predict(X_length.reshape(-1, 1)), color = 'blue')
plt.title('weight vs length')
plt.xlabel('length')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
plt.scatter(X_height, y)
plt.plot(X_height, regressor_height.predict(X_height.reshape(-1, 1)), color = 'blue')
plt.title('weight vs height')
plt.xlabel('length')
plt.ylabel('height')
# Out:
# Text(0, 0.5, 'height')

# %% [markdown]
# ## MSE

# %%
mse = np.sum((regressor_length.predict(X_length.reshape(-1,1)) - y)**2)/len(y)
mse
# Out:
# 0.0962706880784303

# %% [markdown]
# ## RMSE

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 0.31027518121569164

# %% [markdown]
# ## Coefficient of Determindation

# %%
ssres = np.sum((regressor_length.predict(X_length.reshape(-1,1)) - y)**2)
sstot = np.sum((y - np.mean(y))**2)
r2 = 1 - (ssres/sstot)
r2
# Out:
# 0.7115246655482681

# %% [markdown]
# ## Residual Plot

# %%
import seaborn as sns

sns.residplot(x=X_length, y=y,color='r')
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
# Out:
# Text(0, 0.5, 'Residuals')
